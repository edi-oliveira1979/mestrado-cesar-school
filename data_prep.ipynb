# %% [markdown]
# <a href="https://colab.research.google.com/github/edi-oliveira1979/mestrado-cesar-school/blob/main/data_prep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import userdata
import os

# Recupera as credenciais das Secrets do Colab
os.environ['KAGGLE_USERNAME'] = userdata.get('KAGGLE_USERNAME')
os.environ['KAGGLE_KEY'] = userdata.get('KAGGLE_KEY')

# Agora você pode baixar o dataset sem expor sua chave!
# !kaggle competitions download -c home-credit-default-risk
